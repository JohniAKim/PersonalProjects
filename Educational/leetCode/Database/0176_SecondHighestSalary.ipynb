# %% [markdown]
# ## 176. Second Highest Salary

# %% [markdown]
# **Change Log**
#
# | Date | Description |
# | ---------- | ---------- |
# | 2022-04-11 | Initialize |

# %% [markdown]
# ## Summary

# %% [markdown]
# Get the second highest `salary` from the `Employee` table.

# %% [markdown]
# #### SQL Schema
#
# ```sql
# Create table If Not Exists Employee (id int, salary int)
# Truncate table Employee
# insert into Employee (id, salary) values ('1', '100')
# insert into Employee (id, salary) values ('2', '200')
# insert into Employee (id, salary) values ('3', '300')
#
# ```

# %% [markdown]
# Table: Employee
#
# ```
# +-------------+------+
# | Column Name | Type |
# +-------------+------+
# | id          | int  |
# | salary      | int  |
# +-------------+------+
# ```
# id is the primary key column for this table.
# Each row of this table contains information about the salary of an employee.

# %% [markdown]
# ## Problem
#
# Write an SQL query to report the second highest salary from the `Employee` table. If there is no second highest salary, the query should report `null`.

# %% [markdown]
# The query result format is in the following example.
#
#
#
# #### Example 1:
#
# **Input:**
# ```
# Employee table:
# +----+--------+
# | id | salary |
# +----+--------+
# | 1  | 100    |
# | 2  | 200    |
# | 3  | 300    |
# +----+--------+
# ```
# **Output:**
# ```
# +---------------------+
# | SecondHighestSalary |
# +---------------------+
# | 200                 |
# +---------------------+
# ```
#
# #### Example 2:
#
#
# **Input:**
# ```
# Employee table:
# +----+--------+
# | id | salary |
# +----+--------+
# | 1  | 100    |
# +----+--------+
# ```
# **Output:**
# ```
# +---------------------+
# | SecondHighestSalary |
# +---------------------+
# | null                |
# +---------------------+
# ```
#
# ---

# %% [markdown]
# ## Solution 1 - MSSQL
#
# There may be all kinds of fancy ways to do this, but the easiest one that comes to mind is to use a subquery in the `WHERE` clause to find the `max(salary)` and then filter using that.

# %% [markdown]
# ```sql
# SELECT  max(salary) AS SecondHighestSalary
# FROM    Employee e
# WHERE   salary < (SELECT max(salary) FROM Employee)
# ```

# %% [markdown]
# ### Result
#
# ![image.png](attachment:325007bd-fdd8-4af8-bdf5-dcaa0d3d5c6d.png)

# %% [markdown]
# The results look good.

# %% [markdown]
# ## Solution 2 - MSSQL - Add NOLOCK
#
# Same as *Solution 1* except we add the NOLOCK table hint.

# %% [markdown]
# ```sql
# SELECT  max(salary) AS SecondHighestSalary
# FROM    Employee e (NOLOCK)
# WHERE   salary < (SELECT max(salary) FROM Employee (NOLOCK))
# ```

# %% [markdown]
# ### Result
#
# ![image.png](attachment:86b35d8e-99f0-444c-bf44-59e4fbb717bb.png)
#
# Nearly identical results with the `NOLOCK` directive.
